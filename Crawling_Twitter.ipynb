# %% [markdown]
# <a href="https://colab.research.google.com/github/pandu1992/PraktikumDataScience/blob/main/Crawling_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Twitter Auth Token
twitter_auth_token = '4fd60f984eebce8f7bb9dd998f84fb8ef08a96c1'

# Twitter Auth Token
twitter_auth_token = '4fd60f984eebce8f7bb9dd998f84fb8ef08a96c1'

# Install necessary Python package
# !pip install pandas

# Install Node.js (tweet-harvest requires Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg
# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list
# !sudo apt-get update
# !sudo apt-get install nodejs -y
# !node -v

# Crawl Twitter Data using tweet-harvest
filename = 'gantiseragamsekolah.csv'
search_keyword = 'ganti seragam sekolah until:2024-09-22 since:2024-04-09 lang:id'
limit = 500
# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}

# Import libraries for data processing and visualization
import pandas as pd
import os

# Check if running in Google Colab
try:
    from google.colab import files
    is_colab = True
except ImportError:
    is_colab = False

# Step to handle file reading based on environment
if is_colab:
    # In Google Colab: check if the file exists after crawling
    if os.path.exists(filename):
        input_path = filename  # Use the filename directly
    else:
        # If file doesn't exist, prompt the user to upload it
        print("File not found. Please upload the 'gantiseragamsekolah.csv' file.")
        uploaded = files.upload()  # This will prompt file upload
        input_path = 'gantiseragamsekolah.csv'  # The uploaded file's name
else:
    # Local environment: specify the full path to the file
    input_path = 'D:/gantiseragamsekolah.csv'  # Replace with the correct path where the file is located

# Check if the file exists before attempting to read
if os.path.exists(input_path):
    df = pd.read_csv(input_path)  # Reading the CSV file
    print(f"File '{input_path}' loaded successfully.")
else:
    print(f"Error: File '{input_path}' not found. Please check the path and try again.")

# Save the processed file based on the environment
if 'df' in locals():
    if is_colab:
        # In Google Colab, save to the default directory
        output_path = '/content/gantiseragamsekolah_output.csv'
    else:
        # On a local machine, use the specified path
        output_path = 'D:/gantiseragamsekolah_output.csv'

    # Save the DataFrame to a new file without the index
    df.to_csv(output_path, index=False)
    print(f'File successfully saved at {output_path}')

    # If in Colab, provide a download link for the saved file
    if is_colab:
        files.download(output_path)
else:
    print('DataFrame not found. Skipping the save operation.')
# Out:
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 257 kB in 2s (156 kB/s)
# Reading package lists... Done
# ...
